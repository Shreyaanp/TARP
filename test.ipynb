# %%
import numpy as np

# Create some arrays
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

# Save to .npz file
np.savez('arrays.npz', array1=array1, array2=array2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
data = np.load('tiny_nerf_data.npz')

# Print all keys in the .npz file
print("Keys in the .npz file:", data.files)

# Extract data
images = data['images']
poses = data['poses']
focal = data['focal']

# Get image dimensions
H, W = images.shape[1:3]

# Print shapes of the loaded arrays
print("Images shape:", images.shape)
print("Poses shape:", poses.shape)
print("Focal length:", focal)

# Extract test image and pose
testimg, testpose = images[102], poses[101]

# Limit to first 100 images and remove alpha channel from images
images = images[:100,...,:3]
poses = poses[:100]

# Display the test image
plt.imshow(testimg)
plt.show()
# Out:
# Keys in the .npz file: ['images', 'poses', 'focal']
# Images shape: (106, 100, 100, 3)
# Poses shape: (106, 4, 4)
# Focal length: 138.88887889922103

# %%
# !pip install npzviewer
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#      --------------------------------------- 0.0/50.1 MB 435.7 kB/s eta 0:01:55
#      --------------------------------------- 0.1/50.1 MB 363.1 kB/s eta 0:02:18
#      --------------------------------------- 0.1/50.1 MB 435.7 kB/s eta 0:01:55
#      --------------------------------------- 0.1/50.1 MB 479.3 kB/s eta 0:01:45
#      --------------------------------------- 0.2/50.1 MB 523.5 kB/s eta 0:01:36
#      --------------------------------------- 0.2/50.1 MB 573.4 kB/s eta 0:01:27
# ...
